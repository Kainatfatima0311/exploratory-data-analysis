# %% [markdown]
# # Data Understanding
#
# ## Objective
#
# Learn how to explore a dataset using Pandas before cleaning and analysis.

# %%
#libraries
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
#loading datasets
df = pd.read_csv("../datasets/sample_data.csv")

# %% [markdown]
# ## Display the First Five Rows

# %%
#display first five rows
df.head()
# Out:
#    Employee_ID         Name  Gender  Age Department        City  \
# 0         1001     Ali Khan    Male   25         IT      Lahore
# 1         1002   Sara Ahmed  Female   28         HR     Karachi
# 2         1003   Ahmed Raza    Male   31    Finance   Islamabad
# 3         1004  Fatima Noor  Female   24  Marketing  Faisalabad
# 4         1005   Hassan Ali    Male   29         IT      Lahore
#
#    Experience_Years  Salary  Performance_Score Joining_Date  Is_Remote  \
# 0                 2   65000                8.5   2023-01-15       True
# 1                 5   85000                9.2   2020-06-20      False
# 2                 7   98000                8.9   2018-03-10       True
# 3                 1   55000                7.8   2024-02-01      False
# 4                 4   82000                8.4   2021-09-12       True
#
#                    Email
# 0     ali.khan@email.com
# 1   sara.ahmed@email.com
# 2   ahmed.raza@email.com
# 3  fatima.noor@email.com
# ...

# %% [markdown]
# ## Display the Last Five Rows

# %%
#display last five rows
df.tail()
# Out:
#    Employee_ID          Name  Gender  Age Department        City  \
# 5         1006  Ayesha Malik  Female   35    Finance     Karachi
# 6         1007   Umar Farooq    Male   27      Sales  Rawalpindi
# 7         1008  Zainab Tariq  Female   30         IT   Islamabad
# 8         1009   Bilal Ahmed    Male   26    Support      Multan
# 9         1010    Maria Khan  Female   33         HR      Lahore
#
#    Experience_Years  Salary  Performance_Score Joining_Date  Is_Remote  \
# 5                10  120000                9.7   2015-07-18      False
# 6                 3   72000                8.0   2022-05-25       True
# 7                 6   95000                9.1   2019-11-08       True
# 8                 2   60000                7.9   2023-04-03      False
# 9                 8  105000                9.4   2017-08-15       True
#
#                     Email
# 5  ayesha.malik@email.com
# 6   umar.farooq@email.com
# 7  zainab.tariq@email.com
# 8   bilal.ahmed@email.com
# ...

# %% [markdown]
# ## Check Dataset Shape

# %%
# Display the number of rows and columns
df.shape
# Out:
# (10, 12)

# %% [markdown]
# ## Display Column Names

# %%
# Display all column names
df.columns
# Out:
# Index(['Employee_ID', 'Name', 'Gender', 'Age', 'Department', 'City',
#        'Experience_Years', 'Salary', 'Performance_Score', 'Joining_Date',
#        'Is_Remote', 'Email'],
#       dtype='object')

# %% [markdown]
# ## Check Data Types

# %%
# Display the data type of every column
df.dtypes
# Out:
# Employee_ID            int64
# Name                  object
# Gender                object
# Age                    int64
# Department            object
# City                  object
# Experience_Years       int64
# Salary                 int64
# Performance_Score    float64
# Joining_Date          object
# Is_Remote               bool
# Email                 object
# dtype: object

# %% [markdown]
# ## Complete Dataset Information

# %%
# Display complete information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Employee_ID        10 non-null     int64
#  1   Name               10 non-null     object
#  2   Gender             10 non-null     object
#  3   Age                10 non-null     int64
#  4   Department         10 non-null     object
#  5   City               10 non-null     object
#  6   Experience_Years   10 non-null     int64
#  7   Salary             10 non-null     int64
#  8   Performance_Score  10 non-null     float64
#  9   Joining_Date       10 non-null     object
#  10  Is_Remote          10 non-null     bool
#  11  Email              10 non-null     object
# dtypes: bool(1), float64(1), int64(4), object(6)
# memory usage: 1022.0+ bytes

# %% [markdown]
# ## Statistical Summary

# %%
# Display statistical summary of numerical columns
df.describe()
# Out:
#        Employee_ID        Age  Experience_Years         Salary  \
# count     10.00000  10.000000         10.000000      10.000000
# mean    1005.50000  28.800000          4.800000   83700.000000
# std        3.02765   3.521363          2.936362   21029.344577
# min     1001.00000  24.000000          1.000000   55000.000000
# 25%     1003.25000  26.250000          2.250000   66750.000000
# 50%     1005.50000  28.500000          4.500000   83500.000000
# 75%     1007.75000  30.750000          6.750000   97250.000000
# max     1010.00000  35.000000         10.000000  120000.000000
#
#        Performance_Score
# count          10.000000
# mean            8.690000
# std             0.667416
# min             7.800000
# 25%             8.100000
# 50%             8.700000
# 75%             9.175000
# max             9.700000

# %% [markdown]
# # Observation
#
# - Checked the dataset size.
# - Displayed column names.
# - Verified data types.
# - Viewed complete dataset information.
# - Generated statistical summary.

# %% [markdown]
# # Conclusion
#
# Data Understanding is the first coding step in EDA. It provides a clear overview of the dataset before data cleaning and visualization.
